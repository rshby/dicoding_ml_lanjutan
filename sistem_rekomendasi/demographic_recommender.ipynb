# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(context="talk")

# %%
df = (pd.read_csv("dataset/IMDb movies.csv").loc[:, "original_title":"votes"].drop(["language", "production_company", "description"], axis="columns"))
df["year"] = df["year"].str.replace("TV Movie 2019", "2019")
df = df.astype({"avg_vote":"float", "votes":"float", "duration":"float", "year":"float"})
# Out:
# C:\Users\ROG\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#                 original_title  year date_published  \
# 0                   Miss Jerry   NaN     1894-10-09
# 1  The Story of the Kelly Gang   NaN     1906-12-26
# 2               Den sorte drøm   NaN     1911-08-19
# 3                    Cleopatra   NaN     1912-11-13
# 4                    L'Inferno   NaN     1911-03-06
#
#                        genre  duration           country  \
# 0                    Romance      45.0               USA
# 1    Biography, Crime, Drama      70.0         Australia
# 2                      Drama      53.0  Germany, Denmark
# 3             Drama, History     100.0               USA
# 4  Adventure, Drama, Fantasy      68.0             Italy
#
#                               director                                 writer  \
# 0                      Alexander Black                        Alexander Black
# 1                         Charles Tait                           Charles Tait
# 2                            Urban Gad  Urban Gad, Gebhard Schätzler-Perasini
# 3                   Charles L. Gaskill                       Victorien Sardou
# 4  Francesco Bertolini, Adolfo Padovan                        Dante Alighieri
#
#                                               actors  avg_vote   votes
# 0  Blanche Bayliss, William Courtenay, Chauncey D...       5.9   154.0
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...       6.1   589.0
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...       5.8   188.0
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...       5.2   446.0
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...       7.0  2237.0

# %% [markdown]
# ## Sorting

# %%
df.sort_values("avg_vote", ascending=False).head(10)
# Out:
#                           original_title    year date_published  \
# 83275                    Suvarna Sundari  2019.0     2019-05-31
# 84995                        Notuku Potu  2017.0     2017-03-24
# 55310                             Jeeudo     NaN     2020-02-27
# 56032                                 Ek     NaN     2019-06-14
# 54217  Lejos de Casa pelicula Venezolana     NaN     2020-03-19
# 84434                Vaarthakal Ithuvare  2019.0     2019-11-22
# 56329                          Meka Suri     NaN     2020-07-31
# 58809                      Hopeful Notes     NaN     2010-12-15
# 54166                The Moving on Phase     NaN     2020-05-11
# 55170                               Isha     NaN     2020-02-28
#
#                   genre  duration    country          director  \
# 83275  Action, Thriller     120.0      India         Msn Surya
# 84995   Horror, Mystery     121.0      India      Basheed S.K.
# 55310    Drama, Romance     150.0      India     Aalmist Subba
# 56032     Action, Drama     129.0      India     Sampath Rudra
# 54217    Drama, History      87.0  Venezuela    Abner Official
# 84434            Comedy     121.0      India        Manoj Nair
# 56329   Crime, Thriller      86.0      India  Trinadh Velisila
# 58809             Drama      94.0        USA    Valerio Zanoli
# 54166            Comedy      85.0        USA     Don Tjernagel
# 55170     Drama, Horror     118.0      India       Jose Thomas
#
#                               writer  \
# 83275                            NaN
# 84995                            NaN
# 55310  Aalmist Subba, Chanchal Thapa
# 56032                  Harik Krishna
# 54217   Dariana Jozh, Abner Official
# 84434                     Manoj Nair
# 56329                            NaN
# 58809                 Valerio Zanoli
# 54166                  Don Tjernagel
# 55170                    Jose Thomas
#
#                                                   actors  avg_vote   votes
# 83275  Shamna Kasim, Sakshi Chaudhary, Jaya Prada, Av...       9.9   896.0
# 84995          Mumait Khan, Manisha Koirala, Arjun Sarja       9.8   926.0
# 55310  Prashant Baraili, Davina, Pranisha Gahatraj, P...       9.8   130.0
# 56032  Bishnu Adhikari, Himanshi Khurana, Aparna Shar...       9.8   527.0
# 54217  Angibell, Gabriel Buitrago, Darwing, Dariana J...       9.8   133.0
# 84434  Siju Wilson, Nandu, Vinay Forrt, Mammukoya, Al...       9.7   473.0
# 56329  Abhinay, Naresh Byreddy, Sharat Kumar, Sravan,...       9.7  1126.0
# 58809  Walter Nudo, Colin Ross, Ian Poland, Laural Me...       9.7   669.0
# 54166  Matt Anderson, Clint Boevers, Jillian Brown, C...       9.5   172.0
# 55170                      Kishore Satya, Abhishek Vinod       9.5   392.0

# %% [markdown]
# ## Step 1: Filtering

# %%
genre = ["Horror", "Drama"]
year = [2018, 2020]
duration = [90, 150]
top_k = 10

hasil_perdiksi = df[(df["year"].between(year[0], year[1])) & (df["duration"].between(duration[0], duration[1])) & (df["genre"].str.contains("Drama")) & (df["genre"].str.contains("Crime"))]

# %%
hasil_perdiksi
# Out:
#                                    original_title    year date_published  \
# 65788                             Line of Descent  2019.0     2019-12-04
# 66222                                   Galveston  2018.0     2020-08-06
# 67500  Extremely Wicked, Shockingly Evil and Vile  2019.0     2019-05-09
# 68330                                City of Lies  2018.0     2019-01-10
# 69533                              A Lonely Woman  2018.0     2018-03-23
# ...                                           ...     ...            ...
# 85739                 Il sindaco del Rione Sanità  2019.0     2019-09-30
# 85760                    Pasmerkti. Kauno Romanas  2019.0     2019-02-22
# 85778                     Shabi Ke Mah Kamel Shod  2019.0     2019-06-05
# 85780                          Metri Shesh Va Nim  2019.0     2019-03-17
# 85784                                     Villain  2020.0     2020-02-28
#
#                          genre  duration    country          director  \
# 65788             Crime, Drama     108.0        USA  Rohit Karn Batra
# 66222     Action, Crime, Drama      91.0        USA   Mélanie Laurent
# 67500  Biography, Crime, Drama     110.0        USA     Joe Berlinger
# 68330  Biography, Crime, Drama     112.0    UK, USA       Brad Furman
# 69533     Action, Crime, Drama     105.0        USA     Juven Cavazos
# ...                        ...       ...        ...               ...
# 85739             Crime, Drama     115.0      Italy     Mario Martone
# 85760   Crime, Drama, Thriller      94.0  Lithuania   Ramunas Rudokas
# 85778    Crime, Drama, Romance     131.0       Iran      Narges Abyar
# 85780     Action, Crime, Drama     131.0       Iran    Saeed Roustayi
# 85784     Action, Crime, Drama      97.0         UK  Philip Barantini
#
#                                       writer  \
# 65788                       Rohit Karn Batra
# 66222         Nic Pizzolatto, Nic Pizzolatto
# 67500      Elizabeth Kendall, Michael Werwie
# 68330  Randall Sullivan, Christian Contreras
# 69533                          Juven Cavazos
# ...                                      ...
# 85739      Eduardo De Filippo, Mario Martone
# 85760                      Erikas Kundreckas
# 85778         Narges Abyar, Morteza Esfahani
# 85780                         Saeed Roustayi
# 85784                Greg Hall, George Russo
#
#                                                   actors  avg_vote    votes
# 65788  Brendan Fraser, Prem Chopra, Abhay Deol, Ronit...       4.7    376.0
# 66222  Ben Foster, Jeffrey Grover, Christopher Amitra...       6.2  10901.0
# 67500  Lily Collins, Zac Efron, Angela Sarafyan, Sydn...       6.6  73071.0
# 68330  Johnny Depp, Forest Whitaker, Toby Huss, Dayto...       6.3   4854.0
# 69533  Youlika Skafida, Beau Yotty, Joe Grisaffi, Mic...       2.6    104.0
# ...                                                  ...       ...      ...
# 85739  Francesco Di Leva, Adriano Pantaleo, Roberto D...       5.1    450.0
# 85760  Ramunas Rudokas, Agne Sataite, Sarunas Datenis...       6.1    282.0
# 85778  Elnaz Shakerdust, Hootan Shakiba, Fereshteh Sa...       6.7   1442.0
# 85780  Payman Maadi, Navid Mohammadzadeh, Parinaz Iza...       7.9   5658.0
# 85784  Craig Fairbrass, Robert Glenister, George Russ...       5.7    649.0
#
# [275 rows x 11 columns]

# %% [markdown]
# ## Step 2: Scoring
# tinggal pakai `"avg_vote"`

# %% [markdown]
# ## Step 3: Sorting

# %%
hasil_perdiksi.sort_values("avg_vote", ascending=False).head(top_k)
# Out:
#            original_title    year date_published                    genre  \
# 82239               Joker  2019.0     2019-10-03   Crime, Drama, Thriller
# 83601              Praana  2019.0     2019-01-18     Crime, Drama, Horror
# 82651              Gultoo  2018.0     2018-04-13             Crime, Drama
# 77075         Juzni vetar  2018.0     2018-10-23   Crime, Drama, Thriller
# 83715      Manbiki kazoku  2018.0     2018-09-13             Crime, Drama
# 82407    Lof mér að falla  2018.0     2018-09-07  Biography, Crime, Drama
# 84912          Knives Out  2019.0     2019-12-05     Comedy, Crime, Drama
# 83774          Sonchiriya  2019.0     2019-03-01     Action, Crime, Drama
# 85780  Metri Shesh Va Nim  2019.0     2019-03-17     Action, Crime, Drama
# 83809               Badla  2019.0     2019-12-07    Crime, Drama, Mystery
#
#        duration                    country              director  \
# 82239     122.0                USA, Canada         Todd Phillips
# 83601     107.0                      India          V.K. Prakash
# 82651     128.0                      India   Janardhan Chikkanna
# 77075     130.0                     Serbia       Milos Avramovic
# 83715     121.0                      Japan      Hirokazu Koreeda
# 82407     136.0  Iceland, Finland, Germany  Baldvin Zophoníasson
# 84912     130.0                        USA          Rian Johnson
# 83774     143.0                      India      Abhishek Chaubey
# 85780     131.0                       Iran        Saeed Roustayi
# 83809     118.0                      India           Sujoy Ghosh
#
#                                              writer  \
# 82239                   Todd Phillips, Scott Silver
# 83601                              Rajesh Jayaraman
# 82651                                           NaN
# 77075             Milos Avramovic, Petar Mihajlovic
# 83715            Hirokazu Koreeda, Hirokazu Koreeda
# 82407  Birgir Örn Steinarsson, Baldvin Zophoníasson
# 84912                                  Rian Johnson
# 83774                Abhishek Chaubey, Sudip Sharma
# 85780                                Saeed Roustayi
# 83809                      Oriol Paulo, Sujoy Ghosh
#
#                                                   actors  avg_vote     votes
# 82239  Joaquin Phoenix, Robert De Niro, Zazie Beetz, ...       8.5  855097.0
# 83601                                       Nithya Menen       8.4     783.0
# 82651  Naveen Shankar, Sonu Gowda, Avinash, Rangayana...       8.3     812.0
# 77075  Milos Bikovic, Miodrag Radonjic, Dragan Bjelog...       8.1    9433.0
# 83715  Lily Franky, Sakura Andô, Kirin Kiki, Mayu Mat...       8.0   56701.0
# 82407  Elín Sif Halldórsdóttir, Eyrún Björk Jakobsdót...       8.0     680.0
# 84912  Daniel Craig, Chris Evans, Ana de Armas, Jamie...       7.9  377903.0
# 83774  Sushant Singh Rajput, Bhumi Pednekar, Manoj Ba...       7.9    6644.0
# 85780  Payman Maadi, Navid Mohammadzadeh, Parinaz Iza...       7.9    5658.0
# 83809  Amitabh Bachchan, Taapsee Pannu, Amrita Singh,...       7.8   20874.0

# %% [markdown]
# # Improve Demographic Recomendation System
# bikin scoring manual dengan formula sendiri

# %%
def imdb_score(df, q=0.7):
    df = df.copy()
    m = df["votes"].quantile(q)
    C = (df["avg_vote"] * df["votes"])/(df["votes"].sum())
    df = df[df["avg_vote"] > m]
    df["score"] = (df["avg_vote"] * df["votes"] + (C + m)) / (df["votes"] + m)
    return df

# %%
recommendation = imdb_score(df)

# %%
m = df["votes"].quantile(0.6)
C = (df["avg_vote"] * df["votes"])/(df["votes"].sum())
df = df.loc[df["votes"] > m]
df["socer"] = (df["avg_vote"] * df["votes"] + (C + m)) / (df["votes"] + m)
# Out:
# C:\Users\ROG\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df.loc[df["votes"] > 10000]
# Out:
#                                          original_title    year  \
# 47                                The Birth of a Nation     NaN
# 76     Intolerance: Love's Struggle Throughout the Ages     NaN
# 165                        Das Cabinet des Dr. Caligari     NaN
# 251                                             The Kid     NaN
# 252                                           Körkarlen     NaN
# ...                                                 ...     ...
# 85735                                       Da 5 Bloods  2020.0
# 85747                               The Kissing Booth 2  2020.0
# 85761                              J'ai perdu mon corps  2019.0
# 85811                                  Falling Inn Love  2019.0
# 85839                                   Coffee & Kareem  2020.0
#
#       date_published                      genre  duration  country  \
# 47        1915-03-21        Drama, History, War     195.0      USA
# 76        1918-02-24             Drama, History     163.0      USA
# 165       1920-02-27   Fantasy, Horror, Mystery      76.0  Germany
# 251       1923-11-26      Comedy, Drama, Family      68.0      USA
# 252             1922     Drama, Fantasy, Horror     107.0   Sweden
# ...              ...                        ...       ...      ...
# 85735     2020-06-12      Adventure, Drama, War     154.0      USA
# 85747     2020-07-24            Comedy, Romance     134.0  UK, USA
# 85761     2019-11-29  Animation, Drama, Fantasy      81.0   France
# 85811     2019-08-29            Comedy, Romance      98.0      USA
# 85839     2020-04-03             Action, Comedy      88.0      USA
#
#               director                              writer  \
# 47       D.W. Griffith  Thomas Dixon Jr., Thomas Dixon Jr.
# 76       D.W. Griffith           D.W. Griffith, Anita Loos
# 165       Robert Wiene           Carl Mayer, Hans Janowitz
# 251    Charles Chaplin                     Charles Chaplin
# 252    Victor Sjöström     Selma Lagerlöf, Victor Sjöström
# ...                ...                                 ...
# 85735        Spike Lee           Danny Bilson, Paul De Meo
# 85747   Vince Marcello        Vince Marcello, Jay S Arnold
# 85761    Jérémy Clapin    Jérémy Clapin, Guillaume Laurant
# 85811     Roger Kumble   Elizabeth Hackett, Hilary Galanoy
# 85839    Michael Dowse                          Shane Mack
#
#                                                   actors  avg_vote     votes  \
# 47     Henry B. Walthall, Lillian Gish, Mae Marsh, Mi...       6.3   22213.0
# 76     Lillian Gish, Mae Marsh, Robert Harron, F.A. T...       7.8   13875.0
# 165    Werner Krauss, Conrad Veidt, Friedrich Feher, ...       8.1   55601.0
# 251    Carl Miller, Edna Purviance, Jackie Coogan, Ch...       8.3  109038.0
# 252    Victor Sjöström, Hilda Borgström, Tore Svennbe...       8.1   10054.0
# ...                                                  ...       ...       ...
# 85735  Delroy Lindo, Jonathan Majors, Clarke Peters, ...       6.5   29694.0
# 85747  Joey King, Joel Courtney, Jacob Elordi, Molly ...       5.9   15189.0
# 85761  Hakim Faris, Victoire Du Bois, Patrick d'Assum...       7.6   24010.0
# 85811  Christina Milian, Adam Demos, Jeffrey Bowyer-C...       5.6   14108.0
# 85839  Ed Helms, Taraji P. Henson, Terrence Little Ga...       5.1   10627.0
#
#           socer
# 47     6.127789
# 76     7.453047
# 165    8.006000
# 251    8.250395
# 252    7.609574
# ...         ...
# 85735  6.365210
# 85747  5.670606
# 85761  7.401115
# 85811  5.368978
# 85839  4.831065
#
# [8501 rows x 12 columns]
